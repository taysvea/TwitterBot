# %% [markdown]
# # Bot Skeleton

# %% [markdown]
# The next cell will authenticate your bot based on your keys and tokens. See the [Tweepy tutorial](https://github.com/comp-journalism/UMD-J479V-J779V-Spring2016/blob/master/Weekly/Week_5/Tweepy-skeleton.ipynb) for more details.

# %%
import tweepy

#Setup and authenticate Tweepy
CONSUMER_KEY = "EoCgZlaz4kbuX6qaWfPhkWQJs"
CONSUMER_SECRET = "aYZvsKONPT7LwS8iQgBbowKNIlnIbQtwXQPyqtxcYqCgZ0rwDY"
ACCESS_TOKEN = "758422215733944320-rlMTPLdz6em9AegePS6jV7145YC7zny"
ACCESS_TOKEN_SECRET = "RN6x2AMQhjYTKURhZ3VDGxvC5Hr2y8oonzi4kkPCozE2d"

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)


#for status in api.user_timeline('Humans_of_Syria'):
    #api.retweet(status.id)

    


#api.update_status(status = "Tweet Test")

# %% [markdown]
# The next cell has a number of essential functions that allow your bot to listen to the twitter stream and then respond. The assignment involves fleshing out the editorial logic of the bot and writing code in the sections marked "TODO".

# %%
import random
import json
import time
import pprint


# If debug_mode is True then the bot won't actually tweet. Set debug_mode = False for it to tweet. 
debug_mode = False


# Functions that allow the bot to tweet or reply to tweets
def tweet(status):
    print ("JUST TWEETED: "), status
    # Only *actually* send the tweet on twitter if we're not in debug mode
    if debug_mode == False:
        api.update_status(status)
        
def tweet_with_probability(status, probability):
    # Change the probability of tweeting variable to affect how often the bot tweets
    rand = random.random()
    if rand <= probability:
        print ("JUST TWEETED: "), status
        # Only *actually* send the tweet on twitter if we're not in debug mode
        if debug_mode == False:
            api.update_status(status)
            
#Tweet when keyword is picked up
        
def tweet_reply(status, tweet_to_reply_to):
    screen_name = tweet_to_reply_to["user"]["screen_name"]
    at = "In reply to @"+screen_name 
    reply_to_id = tweet_to_reply_to["id"]
    foo = [ 
           'http://www.therefugeeproject.org/#/1984',
           'https://reported.ly/2015/09/04/buses-of-hope-from-keleti-station-to-austria/', 
           'http://asylumaccess.org/stories/syrian-refugee-family-story/', 
           'https://www.globalfundforwomen.org/nohas-story/',
           'http://time.com/a-syrian-refugee-story/',
           'https://www.theguardian.com/world/2016/jan/26/didnt-think-might-never-see-parents-again-refugee-children-share-their-stories',
           'http://bust.com/feminism/15069-3-syrian-refugee-women-tell-their-stories.html',
           'http://www.unhcr.org/news/latest/2016/6/575154624/10-refugees-compete-2016-olympics-rio.html',
           'http://www.businessinsider.de/syrian-refugee-stories-told-by-humans-of-new-york-2015-12?r=US&IR=T',
           'http://www.haaretz.com/middle-east-news/1.729158',
           'http://latincorrespondent.com/2015/11/central-american-and-mexican-women-facing-refugee-crisis-report-says/'
           
            ]
    status = at + " " + status + (random.choice(foo))
    
    print(random.choice(foo))
    
    #status = at + " " + status + 'http://www.humansofnewyork.com/post/38633154424/seen-in-tehran-iran'
    print ("JUST TWEETED: Hello World"), status
    # To actually have the bot tweet a status message uncomment the next line, it will send the tweet in response to the appropriate tweet. 
    # Only *actually* send the tweet on twitter if we're not in debug mode
    if debug_mode == False:
        api.update_status(status=status, in_reply_to_status_id=reply_to_id)
        
    
    foo = ['http://www.therefugeeproject.org/#/1984',
           'https://reported.ly/2015/09/04/buses-of-hope-from-keleti-station-to-austria/', 
           'http://asylumaccess.org/stories/syrian-refugee-family-story/', 
           'https://www.globalfundforwomen.org/nohas-story/',
           'http://time.com/a-syrian-refugee-story/',
           'https://www.theguardian.com/world/2016/jan/26/didnt-think-might-never-see-parents-again-refugee-children-share-their-stories',
           'http://bust.com/feminism/15069-3-syrian-refugee-women-tell-their-stories.html',
           'http://www.unhcr.org/news/latest/2016/6/575154624/10-refugees-compete-2016-olympics-rio.html',
           'http://www.businessinsider.de/syrian-refugee-stories-told-by-humans-of-new-york-2015-12?r=US&IR=T',
           'http://www.haaretz.com/middle-east-news/1.729158',
           'http://latincorrespondent.com/2015/11/central-american-and-mexican-women-facing-refugee-crisis-report-says/'
          ]
    print(random.choice(foo))
    
# We derive a class that is used to listen to the twitter stream
class TwitterStreamListener(tweepy.StreamListener):
    def __init__(self):
        super(TwitterStreamListener, self).__init__()
        self.num_tweets = 0 
        self.api_count = 0
        self.old_time = time.time()
    
    # Everytime the listener encounters a tweet that matches its filters it will trigger the on_data function
    def on_data(self, data):
        try:
            print ("a tweet found")
            # Increment out counter of tweets
            self.num_tweets = self.num_tweets + 1
               
            
            # The data variable represents the tweet that was detected by the stream listener
            # Here we just parse it as JSON and put it in another variable. 
            tweet_data = json.loads(data)
            
            print(tweet_data)
            # Make sure the bot never interacts with itself
            user = tweet_data["user"]["screen_name"]
            
            user_mentions = tweet_data['entities']['user_mentions']
            print("got here")
            user_mentions_list = []
            for u in user_mentions:
                print("iterating user mentions")
                print(u)
                user_mentions_list.append(u["screen_name"])
            print("got past loop")
            if user == "migrantbot" or "migrantbot" in user_mentions_list:
                print ("dont talk to me")
                # return without doing anything
                return
      
    

            
            # TODO: Add your editorial logic here, some example filters are below
            
            # Possible filters
            # Maybe you don't want to respond to someone's RT
            #if tweet_data["retweeted"] == True
            #    return
            
            # Maybe you don't want to respond to a tweet without a URL
            #if len(tweet_data["entities"]["urls"]) == 0:
            #    return
            
            # Maybe you only want to do something with every Nth tweet since otherwise the bot is tweeting too frequently
            # e.g. Don't do anything unless this is the 5th tweet you've encountered
            if self.num_tweets == 5:
                print ("5")
                self.bot_action(tweet_data)
            
        except Exception as e:
           
            print ("test exception: ") + e
            
            pass
        
        return True
    
    def api_limit_checker(self):
        # API limits are reset every 15 minutes (900 seconds). This checks if we are outside a 15 min window 
        if time.time() - self.old_time > 900: 
            # Reset the timer of window since new window started & Twitter limits refreshed
            self.old_time = time.time()
            #Reset the api counter to 0 since new window started & Twitter limits refreshed
            self.api_count = 0
        else:
            # The bot cannot tweet more than 140 times every 15 minutes (and you should REALLY consider not ever getting close to that as you may trigger Twitters spam detectors)
            # The threshold below is set much more conservatively. It will only let you tweet 5 times in a 15 minute window
            if self.api_count > 5:
                print ("Taking a break")
                # We put the code to sleep for 15-x minutes where x is the current time - old time (when the window started)... So if within 6 minutes we tweet more than 140 times, then the script will halt for the next 15-6=9 minutes until a new window starts
                time.sleep(900 - (time.time() - self.old_time))
                # Since we have slept through the remainder, a new window has started and we reset the API Count as well
                self.api_count = 0
                #Similarly as above, we reset the timer as well since new window has started 
                self.old_time = time.time()
                
    def bot_action(self, tweet_to_reply_to):
        print ("bot action")
        # NOTE: if you'd like your bot to reply, user the tweet_data variable above as the tweet_to_reply_to parameter for this function
        # invoke the API limit checker code, whcih will put bot to sleep if it's too active
        self.api_limit_checker()
        
        # reset the num_tweets counter
        self.num_tweets = 20
        
        print("got to here in bot action")
        # Actually tweet something, just a dummy output right now
        # TODO: Write code that constructs a text to tweet
        try:
            print(tweet_to_reply_to)
            #api.update_status('Hello World',tweet_to_reply_to["id"]) 
            tweet_reply("",tweet_to_reply_to)
        except Exception as e:
            print("Exception in bot action")
            print(e)
       
        print("we think we did something")
        #tweet("Hello world")
        
        # Increment API count
        self.api_count = self.api_count + 1
        
        return 
    
    def on_error(self, status):
        print (status)


def listen():
    print ("listening")
    listener = TwitterStreamListener()
    stream = tweepy.Stream(auth, listener)
    # track_object filters the twitter stream to capture data, can provide a hashtag, word, or screenname amongths other things. See documentation at: https://dev.twitter.com/streaming/overview/request-parameters
    track_object = ["#Syria", "#refugee", "#migrants", "refugee", "refugees", "migrants", "muslim", "islam", "isis", "syrian"]
    
    try:
        # Start filtering the twitter stream
        stream.filter(track=track_object)
        print ("tried")
    except:
        # do nothing in the event of an error
        pass
    return

# %% [markdown]
# The next cell will actually run the bot and set it to listen to Twitter.

# %%
listen()
# Out:
# listening
# a tweet found
# {'lang': 'en', 'id_str': '760597378000887808', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760597378000887808, 'retweet_count': 0, 'text': 'RT @AnnCoulter: Democrats say: But will he vote reliably Dem?  Paul Ryan GOPs say: But will he provide our donors with cheap labor? https:/…', 'geo': None, 'filter_level': 'low', 'retweeted_status': {'lang': 'en', 'id_str': '760590517973442560', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760590517973442560, 'retweet_count': 147, 'text': 'Democrats say: But will he vote reliably Dem?  Paul Ryan GOPs say: But will he provide our donors with cheap labor? https://t.co/Lfv8IgUleQ', 'geo': None, 'filter_level': 'low', 'quoted_status': {'lang': 'en', 'id_str': '759574639102205952', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 759574639102205952, 'retweet_count': 368, 'text': 'This poor vehicle..😨 raped in broad daylight by a muslim😞\n\nI think he needs a job and 2 hugs😊\n\n#ImWithHer \n#BanIslam https://t.co/bj5zUTCchO', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'extended_entities': {'media': [{'display_url': 'pic.twitter.com/bj5zUTCchO', 'id_str': '759574603823886336', 'expanded_url': 'http://twitter.com/2ALAW/status/759574639102205952/photo/1', 'type': 'animated_gif', 'media_url': 'http://pbs.twimg.com/tweet_video_thumb/CoqNE-lUsAATwEn.jpg', 'video_info': {'variants': [{'content_type': 'video/mp4', 'bitrate': 0, 'url': 'https://pbs.twimg.com/tweet_video/CoqNE-lUsAATwEn.mp4'}], 'aspect_ratio': [25, 38]}, 'id': 759574603823886336, 'sizes': {'small': {'w': 200, 'resize': 'fit', 'h': 304}, 'medium': {'w': 200, 'resize': 'fit', 'h': 304}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}, 'large': {'w': 200, 'resize': 'fit', 'h': 304}}, 'indices': [117, 140], 'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/CoqNE-lUsAATwEn.jpg', 'url': 'https://t.co/bj5zUTCchO'}]}, 'entities': {'urls': [], 'user_mentions': [], 'symbols': [], 'hashtags': [{'indices': [95, 105], 'text': 'ImWithHer'}, {'indices': [107, 116], 'text': 'BanIslam'}], 'media': [{'display_url': 'pic.twitter.com/bj5zUTCchO', 'id_str': '759574603823886336', 'expanded_url': 'http://twitter.com/2ALAW/status/759574639102205952/photo/1', 'type': 'photo', 'media_url': 'http://pbs.twimg.com/tweet_video_thumb/CoqNE-lUsAATwEn.jpg', 'id': 759574603823886336, 'sizes': {'small': {'w': 200, 'resize': 'fit', 'h': 304}, 'medium': {'w': 200, 'resize': 'fit', 'h': 304}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}, 'large': {'w': 200, 'resize': 'fit', 'h': 304}}, 'indices': [117, 140], 'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/CoqNE-lUsAATwEn.jpg', 'url': 'https://t.co/bj5zUTCchO'}]}, 'coordinates': None, 'user': {'lang': 'en', 'id_str': '1075681177', 'default_profile': False, 'name': 'Clinton', 'profile_background_tile': False, 'id': 1075681177, 'geo_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'friends_count': 13502, 'followers_count': 25323, 'is_translator': False, 'profile_text_color': '000000', 'favourites_count': 29677, 'profile_background_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_link_color': 'FF691F', 'following': None, 'screen_name': '2ALAW', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/759275014415867904/Xpm9NNc5_normal.jpg', 'follow_request_sent': None, 'profile_image_url': 'http://pbs.twimg.com/profile_images/759275014415867904/Xpm9NNc5_normal.jpg', 'c ...
# got here
# iterating user mentions
# {'id': 196168350, 'id_str': '196168350', 'screen_name': 'AnnCoulter', 'indices': [3, 14], 'name': 'Ann Coulter'}
# got past loop
# a tweet found
# {'lang': 'en', 'id_str': '760597378361688069', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760597378361688069, 'retweet_count': 0, 'text': 'RT @MINIUSA: “Muslim. Black. Girl.”\xa0The only label that matters is U.S. Olympian. Watch @IbtihajMuhammad speak about her labels.\nhttps://t.…', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'entities': {'urls': [{'display_url': 'amp.twimg.com/v/c01af4de-ace…', 'indices': [139, 140], 'url': 'https://t.co/dmsDdaerCc', 'expanded_url': 'https://amp.twimg.com/v/c01af4de-ace1-4ef4-a98b-83aebcf9ab0c'}], 'user_mentions': [{'id': 334293735, 'id_str': '334293735', 'screen_name': 'MINIUSA', 'indices': [3, 11], 'name': 'MINI USA'}, {'id': 459932105, 'id_str': '459932105', 'screen_name': 'IbtihajMuhammad', 'indices': [88, 104], 'name': 'Ibtihaj Muhammad'}], 'symbols': [], 'hashtags': []}, 'coordinates': None, 'user': {'lang': 'en', 'id_str': '45985344', 'default_profile': False, 'name': 'tkay.', 'profile_background_tile': True, 'id': 45985344, 'geo_enabled': True, 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/324923718/tumblr_lqymet87Pm1qjn120o1_500.gif', 'friends_count': 477, 'followers_count': 786, 'is_translator': False, 'profile_text_color': 'ED0C0C', 'favourites_count': 4642, 'profile_background_color': 'C0DEED', 'profile_sidebar_fill_color': 'B8D7E6', 'profile_link_color': '080808', 'following': None, 'screen_name': 'wholovesteekay', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/741751807823745024/RzhouH5s_normal.jpg', 'follow_request_sent': None, 'profile_image_url': 'http://pbs.twimg.com/profile_images/741751807823745024/RzhouH5s_normal.jpg', 'contributors_enabled': False, 'profile_sidebar_border_color': 'C0DEED', 'profile_use_background_image': True, 'location': 'VA BAby', 'url': None, 'created_at': 'Wed Jun 10 00:07:03 +0000 2009', 'statuses_count': 65057, 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/324923718/tumblr_lqymet87Pm1qjn120o1_500.gif', 'listed_count': 7, 'default_profile_image': False, 'description': 'Madd Braggadocious. AKA. FAMU Alumna.  ⚓️❤️', 'utc_offset': -18000, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/45985344/1349879641', 'protected': False, 'time_zone': 'Central Time (US & Canada)', 'notifications': None, 'verified': False}, 'favorite_count': 0, 'truncated': False, 'retweeted_status': {'lang': 'en', 'id_str': '758305349795389441', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 758305349795389441, 'retweet_count': 840, 'text': '“Muslim. Black. Girl.”\xa0The only label that matters is U.S. Olympian. Watch @IbtihajMuhammad speak about her labels.\nhttps://t.co/dmsDdaerCc', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'entities': {'urls': [{'display_url': 'amp.twimg.com/v/c01af4de-ace…', 'indices': [116, 139], 'url': 'https://t.co/dmsDdaerCc', 'expanded_url': 'https://amp.twimg.com/v/c01af4de-ace1-4ef4-a98b-83aebcf9ab0c'}], 'user_mentions': [{'id': 459932105, 'id_str': '459932105', 'screen_name': 'IbtihajMuhammad', 'indices': [75, 91], 'name': 'Ibtihaj Muhammad'}], 'symbols': [], 'hashtags': []}, 'coordinates': None, 'user': {'lang': 'en', 'id_str': '334293735', 'default_profile': False, 'name': 'MINI USA', 'profile_background_tile': True, 'id': 334293735, 'geo_enabled': True, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'friends_count': 231, 'followers_count': 81902, 'is_translator': False, 'profile_text_color': '333333', 'favourites_count': 2138, 'prof ...
# got here
# iterating user mentions
# {'id': 334293735, 'id_str': '334293735', 'screen_name': 'MINIUSA', 'indices': [3, 11], 'name': 'MINI USA'}
# iterating user mentions
# {'id': 459932105, 'id_str': '459932105', 'screen_name': 'IbtihajMuhammad', 'indices': [88, 104], 'name': 'Ibtihaj Muhammad'}
# got past loop
# a tweet found
# {'lang': 'en', 'id_str': '760597378076467200', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760597378076467200, 'retweet_count': 0, 'text': 'RT @MrLachris: Evidence is mounting terrorists in Ansbach &amp; Wurzburg "acted on instructions from Islamic State." https://t.co/ZRkXEvckJV #I…', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'entities': {'urls': [{'display_url': 'spiegel.de/international/…', 'indices': [117, 140], 'url': 'https://t.co/ZRkXEvckJV', 'expanded_url': 'http://www.spiegel.de/international/germany/investigators-examine-possible-is-links-in-germany-attacks-a-1105636.html'}], 'user_mentions': [{'id': 484999518, 'id_str': '484999518', 'screen_name': 'MrLachris', 'indices': [3, 13], 'name': 'Michael'}], 'symbols': [], 'hashtags': [{'indices': [141, 144], 'text': 'ISIS'}, {'indices': [143, 144], 'text': 'Germany'}]}, 'coordinates': None, 'user': {'lang': 'en-GB', 'id_str': '3430768786', 'default_profile': True, 'name': 'Sara', 'profile_background_tile': False, 'id': 3430768786, 'geo_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'friends_count': 287, 'followers_count': 118, 'is_translator': False, 'profile_text_color': '333333', 'favourites_count': 886, 'profile_background_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_link_color': '0084B4', 'following': None, 'screen_name': 'ode2the1ilove', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/754051325059530752/DMkEI70B_normal.jpg', 'follow_request_sent': None, 'profile_image_url': 'http://pbs.twimg.com/profile_images/754051325059530752/DMkEI70B_normal.jpg', 'contributors_enabled': False, 'profile_sidebar_border_color': 'C0DEED', 'profile_use_background_image': True, 'location': None, 'url': None, 'created_at': 'Wed Aug 19 00:27:06 +0000 2015', 'statuses_count': 3206, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'listed_count': 13, 'default_profile_image': False, 'description': 'If you have never failed you have never lived.... To be the best, you must be able to handle the worst.... #voteleave', 'utc_offset': None, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3430768786/1468614822', 'protected': False, 'time_zone': None, 'notifications': None, 'verified': False}, 'favorite_count': 0, 'truncated': False, 'retweeted_status': {'lang': 'en', 'id_str': '760593671863533568', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760593671863533568, 'retweet_count': 2, 'text': 'Evidence is mounting terrorists in Ansbach &amp; Wurzburg "acted on instructions from Islamic State." https://t.co/ZRkXEvckJV #ISIS #Germany', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'entities': {'urls': [{'display_url': 'spiegel.de/international/…', 'indices': [102, 125], 'url': 'https://t.co/ZRkXEvckJV', 'expanded_url': 'http://www.spiegel.de/international/germany/investigators-examine-possible-is-links-in-germany-attacks-a-1105636.html'}], 'user_mentions': [], 'symbols': [], 'hashtags': [{'indices': [126, 131], 'text': 'ISIS'}, {'indices': [132, 140], 'text': 'Germany'}]}, 'coordinates': None, 'user': {'lang': 'da', 'id_str': '484999518', 'default_profile': False, 'name': 'Michael', 'profile_background_tile': False, 'id': 484999518, 'geo_enabled': True, 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/628794014/xb674405581d6c2b8a10541c99f0c29d.jpg', 'friends_count': 713873, 'followers_count': 715195, 'is_translator': False, 'profile_text ...
# got here
# iterating user mentions
# {'id': 484999518, 'id_str': '484999518', 'screen_name': 'MrLachris', 'indices': [3, 13], 'name': 'Michael'}
# got past loop
# a tweet found
# {'lang': 'en', 'id_str': '760597378697142272', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760597378697142272, 'retweet_count': 0, 'text': 'RT @3z0ooz: The Syrian activist Ahmed Abo AlBraa was killed today in #Aleppo countryside while he was covering the clashes there https://t.…', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'extended_entities': {'media': [{'display_url': 'pic.twitter.com/QTtdrFzbMk', 'id_str': '760597277677412352', 'source_user_id_str': '152949652', 'media_url': 'http://pbs.twimg.com/media/Co4vMbkXYAAYPjr.jpg', 'source_status_id_str': '760597286670000134', 'id': 760597277677412352, 'sizes': {'small': {'w': 680, 'resize': 'fit', 'h': 680}, 'medium': {'w': 960, 'resize': 'fit', 'h': 960}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}, 'large': {'w': 960, 'resize': 'fit', 'h': 960}}, 'indices': [139, 140], 'source_status_id': 760597286670000134, 'media_url_https': 'https://pbs.twimg.com/media/Co4vMbkXYAAYPjr.jpg', 'url': 'https://t.co/QTtdrFzbMk', 'expanded_url': 'http://twitter.com/3z0ooz/status/760597286670000134/photo/1', 'source_user_id': 152949652, 'type': 'photo'}]}, 'entities': {'urls': [], 'user_mentions': [{'id': 152949652, 'id_str': '152949652', 'screen_name': '3z0ooz', 'indices': [3, 10], 'name': 'Abdalaziz Alhamza'}], 'symbols': [], 'hashtags': [{'indices': [69, 76], 'text': 'Aleppo'}], 'media': [{'display_url': 'pic.twitter.com/QTtdrFzbMk', 'id_str': '760597277677412352', 'source_user_id_str': '152949652', 'media_url': 'http://pbs.twimg.com/media/Co4vMbkXYAAYPjr.jpg', 'source_status_id_str': '760597286670000134', 'id': 760597277677412352, 'sizes': {'small': {'w': 680, 'resize': 'fit', 'h': 680}, 'medium': {'w': 960, 'resize': 'fit', 'h': 960}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}, 'large': {'w': 960, 'resize': 'fit', 'h': 960}}, 'indices': [139, 140], 'source_status_id': 760597286670000134, 'media_url_https': 'https://pbs.twimg.com/media/Co4vMbkXYAAYPjr.jpg', 'url': 'https://t.co/QTtdrFzbMk', 'expanded_url': 'http://twitter.com/3z0ooz/status/760597286670000134/photo/1', 'source_user_id': 152949652, 'type': 'photo'}]}, 'coordinates': None, 'user': {'lang': 'en', 'id_str': '48272332', 'default_profile': False, 'name': 'Hakan Tanrıverdi', 'profile_background_tile': False, 'id': 48272332, 'geo_enabled': True, 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/435262680707121152/3NrdNDgp.jpeg', 'friends_count': 1756, 'followers_count': 6880, 'is_translator': False, 'profile_text_color': '2C2C2C', 'favourites_count': 17116, 'profile_background_color': 'FFFFFF', 'profile_sidebar_fill_color': 'FFFFFF', 'profile_link_color': '000000', 'following': None, 'screen_name': 'hatr', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/721712668244099073/k8ZI3LQq_normal.jpg', 'follow_request_sent': None, 'profile_image_url': 'http://pbs.twimg.com/profile_images/721712668244099073/k8ZI3LQq_normal.jpg', 'contributors_enabled': False, 'profile_sidebar_border_color': 'FFFFFF', 'profile_use_background_image': False, 'location': 'Brooklyn', 'url': 'http://www.ichschwoersdir.de/', 'created_at': 'Thu Jun 18 06:45:03 +0000 2009', 'statuses_count': 57723, 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/435262680707121152/3NrdNDgp.jpeg', 'listed_count': 327, 'default_profile_image': False, 'description': 'mostly it-sec, mostly reporting @sz, pgp: https://twitter.com/hatr/status/724603392744673281', 'utc_offset': 7200, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/48272332/1469118284', 'protected': False, 'time_zone': 'Bern', 'notifications': None, 'verified': False}, 'favorite_count': 0, 'truncated': False, 'retweeted_status': {'lang': 'en', 'id_str': '760597286670000134', 'contributors': None,  ...
# got here
# iterating user mentions
# {'id': 152949652, 'id_str': '152949652', 'screen_name': '3z0ooz', 'indices': [3, 10], 'name': 'Abdalaziz Alhamza'}
# got past loop
# a tweet found
# {'lang': 'en', 'id_str': '760597378810384385', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760597378810384385, 'retweet_count': 0, 'text': 'RT @vivelafra: These two Muslim brothers were welcomed into the USA, housed &amp; educated, then they murdered us.  I support #Trump. https://t…', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'extended_entities': {'media': [{'display_url': 'pic.twitter.com/kkzXorcYF2', 'id_str': '760269551179227136', 'source_user_id_str': '3308560736', 'media_url': 'http://pbs.twimg.com/media/Co0FIPOVYAAUcoR.jpg', 'source_status_id_str': '760269879601618944', 'id': 760269551179227136, 'sizes': {'small': {'w': 680, 'resize': 'fit', 'h': 453}, 'large': {'w': 900, 'resize': 'fit', 'h': 600}, 'medium': {'w': 900, 'resize': 'fit', 'h': 600}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}}, 'indices': [143, 144], 'source_status_id': 760269879601618944, 'media_url_https': 'https://pbs.twimg.com/media/Co0FIPOVYAAUcoR.jpg', 'url': 'https://t.co/kkzXorcYF2', 'expanded_url': 'http://twitter.com/vivelafra/status/760269879601618944/photo/1', 'source_user_id': 3308560736, 'type': 'photo'}]}, 'entities': {'urls': [], 'user_mentions': [{'id': 3308560736, 'id_str': '3308560736', 'screen_name': 'vivelafra', 'indices': [3, 13], 'name': 'ViveLaFrance'}], 'symbols': [], 'hashtags': [{'indices': [126, 132], 'text': 'Trump'}], 'media': [{'display_url': 'pic.twitter.com/kkzXorcYF2', 'id_str': '760269551179227136', 'source_user_id_str': '3308560736', 'media_url': 'http://pbs.twimg.com/media/Co0FIPOVYAAUcoR.jpg', 'source_status_id_str': '760269879601618944', 'id': 760269551179227136, 'sizes': {'small': {'w': 680, 'resize': 'fit', 'h': 453}, 'large': {'w': 900, 'resize': 'fit', 'h': 600}, 'medium': {'w': 900, 'resize': 'fit', 'h': 600}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}}, 'indices': [143, 144], 'source_status_id': 760269879601618944, 'media_url_https': 'https://pbs.twimg.com/media/Co0FIPOVYAAUcoR.jpg', 'url': 'https://t.co/kkzXorcYF2', 'expanded_url': 'http://twitter.com/vivelafra/status/760269879601618944/photo/1', 'source_user_id': 3308560736, 'type': 'photo'}]}, 'coordinates': None, 'user': {'lang': 'en', 'id_str': '4198082894', 'default_profile': True, 'name': 'Based', 'profile_background_tile': False, 'id': 4198082894, 'geo_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'friends_count': 1148, 'followers_count': 877, 'is_translator': False, 'profile_text_color': '333333', 'favourites_count': 6692, 'profile_background_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_link_color': '0084B4', 'following': None, 'screen_name': 'LawrenceReid08', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/757811596009758720/Ql6bVHSq_normal.jpg', 'follow_request_sent': None, 'profile_image_url': 'http://pbs.twimg.com/profile_images/757811596009758720/Ql6bVHSq_normal.jpg', 'contributors_enabled': False, 'profile_sidebar_border_color': 'C0DEED', 'profile_use_background_image': True, 'location': None, 'url': None, 'created_at': 'Wed Nov 11 05:32:43 +0000 2015', 'statuses_count': 10191, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'listed_count': 52, 'default_profile_image': False, 'description': 'Main Steam Media is the Enemy\n\n#Trump2016 #PVV', 'utc_offset': None, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4198082894/1468997093', 'protected': False, 'time_zone': None, 'notifications': None, 'verified': False}, 'favorite_count': 0, 'truncated': False, 'retweeted_status': {'lang': 'en', 'id_str': '760269879601618944', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_rep ...
# got here
# iterating user mentions
# {'id': 3308560736, 'id_str': '3308560736', 'screen_name': 'vivelafra', 'indices': [3, 13], 'name': 'ViveLaFrance'}
# got past loop
# 5
# bot action
# got to here in bot action
# {'lang': 'en', 'id_str': '760597378810384385', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760597378810384385, 'retweet_count': 0, 'text': 'RT @vivelafra: These two Muslim brothers were welcomed into the USA, housed &amp; educated, then they murdered us.  I support #Trump. https://t…', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'extended_entities': {'media': [{'display_url': 'pic.twitter.com/kkzXorcYF2', 'id_str': '760269551179227136', 'source_user_id_str': '3308560736', 'media_url': 'http://pbs.twimg.com/media/Co0FIPOVYAAUcoR.jpg', 'source_status_id_str': '760269879601618944', 'id': 760269551179227136, 'sizes': {'small': {'w': 680, 'resize': 'fit', 'h': 453}, 'large': {'w': 900, 'resize': 'fit', 'h': 600}, 'medium': {'w': 900, 'resize': 'fit', 'h': 600}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}}, 'indices': [143, 144], 'source_status_id': 760269879601618944, 'media_url_https': 'https://pbs.twimg.com/media/Co0FIPOVYAAUcoR.jpg', 'url': 'https://t.co/kkzXorcYF2', 'expanded_url': 'http://twitter.com/vivelafra/status/760269879601618944/photo/1', 'source_user_id': 3308560736, 'type': 'photo'}]}, 'entities': {'urls': [], 'user_mentions': [{'id': 3308560736, 'id_str': '3308560736', 'screen_name': 'vivelafra', 'indices': [3, 13], 'name': 'ViveLaFrance'}], 'symbols': [], 'hashtags': [{'indices': [126, 132], 'text': 'Trump'}], 'media': [{'display_url': 'pic.twitter.com/kkzXorcYF2', 'id_str': '760269551179227136', 'source_user_id_str': '3308560736', 'media_url': 'http://pbs.twimg.com/media/Co0FIPOVYAAUcoR.jpg', 'source_status_id_str': '760269879601618944', 'id': 760269551179227136, 'sizes': {'small': {'w': 680, 'resize': 'fit', 'h': 453}, 'large': {'w': 900, 'resize': 'fit', 'h': 600}, 'medium': {'w': 900, 'resize': 'fit', 'h': 600}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}}, 'indices': [143, 144], 'source_status_id': 760269879601618944, 'media_url_https': 'https://pbs.twimg.com/media/Co0FIPOVYAAUcoR.jpg', 'url': 'https://t.co/kkzXorcYF2', 'expanded_url': 'http://twitter.com/vivelafra/status/760269879601618944/photo/1', 'source_user_id': 3308560736, 'type': 'photo'}]}, 'coordinates': None, 'user': {'lang': 'en', 'id_str': '4198082894', 'default_profile': True, 'name': 'Based', 'profile_background_tile': False, 'id': 4198082894, 'geo_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'friends_count': 1148, 'followers_count': 877, 'is_translator': False, 'profile_text_color': '333333', 'favourites_count': 6692, 'profile_background_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_link_color': '0084B4', 'following': None, 'screen_name': 'LawrenceReid08', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/757811596009758720/Ql6bVHSq_normal.jpg', 'follow_request_sent': None, 'profile_image_url': 'http://pbs.twimg.com/profile_images/757811596009758720/Ql6bVHSq_normal.jpg', 'contributors_enabled': False, 'profile_sidebar_border_color': 'C0DEED', 'profile_use_background_image': True, 'location': None, 'url': None, 'created_at': 'Wed Nov 11 05:32:43 +0000 2015', 'statuses_count': 10191, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'listed_count': 52, 'default_profile_image': False, 'description': 'Main Steam Media is the Enemy\n\n#Trump2016 #PVV', 'utc_offset': None, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4198082894/1468997093', 'protected': False, 'time_zone': None, 'notifications': None, 'verified': False}, 'favorite_count': 0, 'truncated': False, 'retweeted_status': {'lang': 'en', 'id_str': '760269879601618944', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_rep ...
# http://www.haaretz.com/middle-east-news/1.729158
# JUST TWEETED: Hello World
# https://www.theguardian.com/world/2016/jan/26/didnt-think-might-never-see-parents-again-refugee-children-share-their-stories
# we think we did something
# a tweet found
# {'lang': 'en', 'id_str': '760597378948800512', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760597378948800512, 'retweet_count': 0, 'text': 'RT @ABCWorldNews: 2016 to be deadliest year for refugees trying to reach Europe; 3,000 people have died so far https://t.co/lOutyhrkc1 http…', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'extended_entities': {'media': [{'display_url': 'pic.twitter.com/BMka29fPd1', 'id_str': '760584413352751104', 'source_user_id_str': '86141342', 'media_url': 'http://pbs.twimg.com/media/Co4jfoOW8AAy9Lm.jpg', 'source_status_id_str': '760584417895124992', 'id': 760584413352751104, 'sizes': {'small': {'w': 680, 'resize': 'fit', 'h': 383}, 'large': {'w': 1200, 'resize': 'fit', 'h': 675}, 'medium': {'w': 1200, 'resize': 'fit', 'h': 675}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}}, 'indices': [139, 140], 'source_status_id': 760584417895124992, 'media_url_https': 'https://pbs.twimg.com/media/Co4jfoOW8AAy9Lm.jpg', 'url': 'https://t.co/BMka29fPd1', 'expanded_url': 'http://twitter.com/ABCWorldNews/status/760584417895124992/photo/1', 'source_user_id': 86141342, 'type': 'photo'}]}, 'entities': {'urls': [{'display_url': 'abcn.ws/2aQISbU', 'indices': [111, 134], 'url': 'https://t.co/lOutyhrkc1', 'expanded_url': 'http://abcn.ws/2aQISbU'}], 'user_mentions': [{'id': 86141342, 'id_str': '86141342', 'screen_name': 'ABCWorldNews', 'indices': [3, 16], 'name': 'World News Tonight'}], 'symbols': [], 'hashtags': [], 'media': [{'display_url': 'pic.twitter.com/BMka29fPd1', 'id_str': '760584413352751104', 'source_user_id_str': '86141342', 'media_url': 'http://pbs.twimg.com/media/Co4jfoOW8AAy9Lm.jpg', 'source_status_id_str': '760584417895124992', 'id': 760584413352751104, 'sizes': {'small': {'w': 680, 'resize': 'fit', 'h': 383}, 'large': {'w': 1200, 'resize': 'fit', 'h': 675}, 'medium': {'w': 1200, 'resize': 'fit', 'h': 675}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}}, 'indices': [139, 140], 'source_status_id': 760584417895124992, 'media_url_https': 'https://pbs.twimg.com/media/Co4jfoOW8AAy9Lm.jpg', 'url': 'https://t.co/BMka29fPd1', 'expanded_url': 'http://twitter.com/ABCWorldNews/status/760584417895124992/photo/1', 'source_user_id': 86141342, 'type': 'photo'}]}, 'coordinates': None, 'user': {'lang': 'en', 'id_str': '296387393', 'default_profile': False, 'name': 'Barbara Kelly', 'profile_background_tile': False, 'id': 296387393, 'geo_enabled': True, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif', 'friends_count': 2081, 'followers_count': 1563, 'is_translator': False, 'profile_text_color': '000000', 'favourites_count': 34833, 'profile_background_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_link_color': '9266CC', 'following': None, 'screen_name': 'BKells8', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3195083831/5953f05818602461ad93a912867cac5e_normal.jpeg', 'follow_request_sent': None, 'profile_image_url': 'http://pbs.twimg.com/profile_images/3195083831/5953f05818602461ad93a912867cac5e_normal.jpeg', 'contributors_enabled': False, 'profile_sidebar_border_color': '000000', 'profile_use_background_image': False, 'location': 'Chester SC', 'url': None, 'created_at': 'Tue May 10 17:34:33 +0000 2011', 'statuses_count': 101780, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif', 'listed_count': 128, 'default_profile_image': False, 'description': 'Graduate of Winthrop College,Rock Hill SC Bachelor of Science in Biology Love gardening, zumba and music.', 'utc_offset': -18000, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/296387393/1454992632', 'protected': False, 'time_zone': 'Quito', 'notifications': None, 'verified': False}, 'favorite_count': 0, 'truncated': F ...
# got here
# iterating user mentions
# {'id': 86141342, 'id_str': '86141342', 'screen_name': 'ABCWorldNews', 'indices': [3, 16], 'name': 'World News Tonight'}
# got past loop
# a tweet found
# {'lang': 'ar', 'id_str': '760597379292729344', 'contributors': None, 'favorited': False, 'source': '<a href="http://zad-muslim.com" rel="nofollow">تطبيق زاد المسلم</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760597379292729344, 'retweet_count': 0, 'text': 'أستغفر الله العظيم وأتوب إليه\n♻️ https://t.co/hP4gVmQsoe', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'entities': {'urls': [{'display_url': 'zad-muslim.com', 'indices': [33, 56], 'url': 'https://t.co/hP4gVmQsoe', 'expanded_url': 'http://zad-muslim.com'}], 'user_mentions': [], 'symbols': [], 'hashtags': []}, 'coordinates': None, 'user': {'lang': 'ar', 'id_str': '2989005242', 'default_profile': True, 'name': 'zmnasmt', 'profile_background_tile': False, 'id': 2989005242, 'geo_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'friends_count': 24, 'followers_count': 6, 'is_translator': False, 'profile_text_color': '333333', 'favourites_count': 3, 'profile_background_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_link_color': '0084B4', 'following': None, 'screen_name': 'zmnasmt', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/556923746200481792/6g5ocG6X_normal.jpeg', 'follow_request_sent': None, 'profile_image_url': 'http://pbs.twimg.com/profile_images/556923746200481792/6g5ocG6X_normal.jpeg', 'contributors_enabled': False, 'profile_sidebar_border_color': 'C0DEED', 'profile_use_background_image': True, 'location': None, 'url': None, 'created_at': 'Sun Jan 18 21:10:05 +0000 2015', 'statuses_count': 9485, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'listed_count': 0, 'default_profile_image': False, 'description': None, 'utc_offset': None, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2989005242/1421615940', 'protected': False, 'time_zone': None, 'notifications': None, 'verified': False}, 'favorite_count': 0, 'truncated': False, 'in_reply_to_user_id': None, 'created_at': 'Tue Aug 02 22:05:21 +0000 2016', 'in_reply_to_user_id_str': None, 'place': None, 'retweeted': False, 'timestamp_ms': '1470175521096'}
# got here
# got past loop
# a tweet found
# {'lang': 'en', 'id_str': '760597380202917892', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760597380202917892, 'retweet_count': 0, 'text': 'RT @wikileaks: Hillary Clinton took cash from, was director of, company that did deals with ISIS https://t.co/4B2rOTG7sl more docs: https:/…', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'entities': {'urls': [{'display_url': 'thecanary.co/2016/07/29/par…', 'indices': [97, 120], 'url': 'https://t.co/4B2rOTG7sl', 'expanded_url': 'http://www.thecanary.co/2016/07/29/paris-strikes-astonishing-partnership-secret-isis-sponsor-ties-hillary-clinton/'}, {'display_url': 'search.wikileaks.org/?query=lafarge…', 'indices': [139, 140], 'url': 'https://t.co/fJGNXEHPHi', 'expanded_url': 'https://search.wikileaks.org/?query=lafarge&exact_phrase=&any_of=&exclude_words=&document_date_start=&document_date_end=&released_date_start=&released_date_end=&include_external_sources=True&new_search=True&order_by=most_relevant#results'}], 'user_mentions': [{'id': 16589206, 'id_str': '16589206', 'screen_name': 'wikileaks', 'indices': [3, 13], 'name': 'WikiLeaks'}], 'symbols': [], 'hashtags': []}, 'coordinates': None, 'user': {'lang': 'en', 'id_str': '2520962647', 'default_profile': True, 'name': 'titatita', 'profile_background_tile': False, 'id': 2520962647, 'geo_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'friends_count': 21, 'followers_count': 18, 'is_translator': False, 'profile_text_color': '333333', 'favourites_count': 19, 'profile_background_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_link_color': '0084B4', 'following': None, 'screen_name': 'tcote5619', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png', 'follow_request_sent': None, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png', 'contributors_enabled': False, 'profile_sidebar_border_color': 'C0DEED', 'profile_use_background_image': True, 'location': None, 'url': None, 'created_at': 'Sat May 24 17:25:35 +0000 2014', 'statuses_count': 2440, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'listed_count': 6, 'default_profile_image': True, 'description': None, 'utc_offset': None, 'protected': False, 'time_zone': None, 'notifications': None, 'verified': False}, 'favorite_count': 0, 'truncated': False, 'retweeted_status': {'lang': 'en', 'id_str': '760145201008668672', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760145201008668672, 'retweet_count': 7820, 'text': 'Hillary Clinton took cash from, was director of, company that did deals with ISIS https://t.co/4B2rOTG7sl more docs: https://t.co/fJGNXEHPHi', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'entities': {'urls': [{'display_url': 'thecanary.co/2016/07/29/par…', 'indices': [82, 105], 'url': 'https://t.co/4B2rOTG7sl', 'expanded_url': 'http://www.thecanary.co/2016/07/29/paris-strikes-astonishing-partnership-secret-isis-sponsor-ties-hillary-clinton/'}, {'display_url': 'search.wikileaks.org/?query=lafarge…', 'indices': [117, 140], 'url': 'https://t.co/fJGNXEHPHi', 'expanded_url': 'https://search.wikileaks.org/?query=lafarge&exact_phrase=&any_of=&exclude_words=&document_date_start=&document_date_end=&released_date_start=&released_date_end=&include_external_sources=True&new_search=True&order_by=most_relevant#results'}], 'user_mentions': [], 'symbols': [], 'hashtags': []}, 'coordinates': None, 'user': {'lang': 'en', 'id_str': '16589206', 'de ...
# got here
# iterating user mentions
# {'id': 16589206, 'id_str': '16589206', 'screen_name': 'wikileaks', 'indices': [3, 13], 'name': 'WikiLeaks'}
# got past loop
# a tweet found
# {'lang': 'en', 'id_str': '760597380391632896', 'contributors': None, 'favorited': False, 'source': '<a href="https://roundteam.co" rel="nofollow">RoundTeam</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760597380391632896, 'retweet_count': 0, 'text': 'RT @USATODAY: Muslim women ask Trump #Canyouhearusnow? https://t.co/ylpUz7MFZ3', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'entities': {'urls': [{'display_url': 'usat.ly/2aydayH', 'indices': [55, 78], 'url': 'https://t.co/ylpUz7MFZ3', 'expanded_url': 'http://usat.ly/2aydayH'}], 'user_mentions': [{'id': 15754281, 'id_str': '15754281', 'screen_name': 'USATODAY', 'indices': [3, 12], 'name': 'USA TODAY'}], 'symbols': [], 'hashtags': [{'indices': [37, 53], 'text': 'Canyouhearusnow'}]}, 'coordinates': None, 'user': {'lang': 'en', 'id_str': '4894482472', 'default_profile': False, 'name': 'News headlines', 'profile_background_tile': False, 'id': 4894482472, 'geo_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'friends_count': 4318, 'followers_count': 16585, 'is_translator': False, 'profile_text_color': '000000', 'favourites_count': 2353, 'profile_background_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_link_color': 'E81C4F', 'following': None, 'screen_name': 'relnews_tw', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/706839927665926144/Wo9FhAa5_normal.jpg', 'follow_request_sent': None, 'profile_image_url': 'http://pbs.twimg.com/profile_images/706839927665926144/Wo9FhAa5_normal.jpg', 'contributors_enabled': False, 'profile_sidebar_border_color': '000000', 'profile_use_background_image': False, 'location': 'United States', 'url': 'http://relnews.com', 'created_at': 'Wed Feb 10 08:54:08 +0000 2016', 'statuses_count': 122812, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'listed_count': 304, 'default_profile_image': False, 'description': 'Latest news headlines US, UK, EU around the World everyday! USA #politics #business #people #sport #pictures http://relnews.com', 'utc_offset': -25200, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4894482472/1458333124', 'protected': False, 'time_zone': 'Pacific Time (US & Canada)', 'notifications': None, 'verified': False}, 'favorite_count': 0, 'truncated': False, 'retweeted_status': {'lang': 'en', 'id_str': '760596219253157888', 'contributors': None, 'favorited': False, 'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760596219253157888, 'retweet_count': 25, 'text': 'Muslim women ask Trump #Canyouhearusnow? https://t.co/ylpUz7MFZ3', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'entities': {'urls': [{'display_url': 'usat.ly/2aydayH', 'indices': [41, 64], 'url': 'https://t.co/ylpUz7MFZ3', 'expanded_url': 'http://usat.ly/2aydayH'}], 'user_mentions': [], 'symbols': [], 'hashtags': [{'indices': [23, 39], 'text': 'Canyouhearusnow'}]}, 'coordinates': None, 'user': {'lang': 'en', 'id_str': '15754281', 'default_profile': False, 'name': 'USA TODAY', 'profile_background_tile': False, 'id': 15754281, 'geo_enabled': False, 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000089862470/7aa9f896147a89917aa047e30ab6ebc2.jpeg', 'friends_count': 916, 'followers_count': 2569865, 'is_translator': False, 'profile_text_color': '000000', 'favourites_count': 1607, 'profile_background_color': '0092D0', 'profile_sidebar_fill_color': 'FFFFFF', 'profile_link_color': '0000FF', 'following': None, 'screen_name': 'USATODAY', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/759073730249261057/pdDI8oF3_normal.jpg', 'follow_request_sent': None, 'profile_image_url': 'http://pbs.twimg.com/profile ...
# got here
# iterating user mentions
# {'id': 15754281, 'id_str': '15754281', 'screen_name': 'USATODAY', 'indices': [3, 12], 'name': 'USA TODAY'}
# got past loop
# a tweet found
# {'lang': 'tr', 'id_str': '760597381549322241', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id_str': '760596747819356160', 'in_reply_to_screen_name': 'furkdjmd', 'id': 760597381549322241, 'retweet_count': 0, 'text': '@furkdjmd Islam birden fazla evliligi helal kılmıştır. Ben sadece dov kismi icin soyledim', 'geo': None, 'filter_level': 'low', 'is_quote_status': False, 'in_reply_to_status_id': 760596747819356160, 'entities': {'urls': [], 'user_mentions': [{'id': 755847427492573184, 'id_str': '755847427492573184', 'screen_name': 'furkdjmd', 'indices': [0, 9], 'name': 'Furkan Çiftçi'}], 'symbols': [], 'hashtags': []}, 'coordinates': None, 'user': {'lang': 'tr', 'id_str': '145372846', 'default_profile': False, 'name': 'papatyagibiyazar✌️', 'profile_background_tile': True, 'id': 145372846, 'geo_enabled': True, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'friends_count': 81774, 'followers_count': 82619, 'is_translator': True, 'profile_text_color': '333333', 'favourites_count': 21493, 'profile_background_color': '131516', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_link_color': '009999', 'following': None, 'screen_name': 'bbayramdogann', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/705132468408602624/TzZzohr-_normal.jpg', 'follow_request_sent': None, 'profile_image_url': 'http://pbs.twimg.com/profile_images/705132468408602624/TzZzohr-_normal.jpg', 'contributors_enabled': False, 'profile_sidebar_border_color': 'EEEEEE', 'profile_use_background_image': True, 'location': 'Alsancak, Etimesgut,Ankara', 'url': 'http://instagram.com/papatyagibiyazar', 'created_at': 'Tue May 18 20:35:05 +0000 2010', 'statuses_count': 1290, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'listed_count': 37, 'default_profile_image': False, 'description': 'Rabbine kulcuk olmaya çalişan ✌️ şiir seven arada yazan Ankaralı uzun boylu birisiyiz Elhamdülillah http://instagram.com/papatyagibiyaz…', 'utc_offset': -18000, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/145372846/1453162476', 'protected': False, 'time_zone': 'Quito', 'notifications': None, 'verified': False}, 'favorite_count': 0, 'truncated': False, 'in_reply_to_user_id': 755847427492573184, 'created_at': 'Tue Aug 02 22:05:21 +0000 2016', 'in_reply_to_user_id_str': '755847427492573184', 'place': None, 'retweeted': False, 'timestamp_ms': '1470175521634'}
# got here
# iterating user mentions
# {'id': 755847427492573184, 'id_str': '755847427492573184', 'screen_name': 'furkdjmd', 'indices': [0, 9], 'name': 'Furkan Çiftçi'}
# got past loop
# a tweet found
# {'lang': 'en', 'id_str': '760597381696131076', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760597381696131076, 'retweet_count': 0, 'text': 'RT @yogital: Battle continues in Aleppo as rebel groups try to break siege. Worst escalation of violence in recent months. #Syria https://t…', 'geo': None, 'filter_level': 'low', 'retweeted_status': {'lang': 'en', 'id_str': '760561606346543109', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760561606346543109, 'retweet_count': 2, 'text': 'Battle continues in Aleppo as rebel groups try to break siege. Worst escalation of violence in recent months. #Syria https://t.co/s4MOhFfdHE', 'geo': None, 'filter_level': 'low', 'quoted_status': {'lang': 'en', 'id_str': '760467154428977152', 'contributors': None, 'favorited': False, 'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760467154428977152, 'retweet_count': 59, 'text': '25-30 dying every day in Aleppo and food will run out in 6 weeks, says under-siege resident: https://t.co/XHnRdFGfMc https://t.co/YmiF22vUbQ', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'extended_entities': {'media': [{'display_url': 'pic.twitter.com/YmiF22vUbQ', 'id_str': '760467152621150208', 'expanded_url': 'http://twitter.com/BBCr4today/status/760467154428977152/photo/1', 'type': 'photo', 'media_url': 'http://pbs.twimg.com/media/Co242J9WIAAghFZ.jpg', 'id': 760467152621150208, 'sizes': {'small': {'w': 680, 'resize': 'fit', 'h': 383}, 'medium': {'w': 1200, 'resize': 'fit', 'h': 675}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}, 'large': {'w': 1920, 'resize': 'fit', 'h': 1080}}, 'indices': [117, 140], 'media_url_https': 'https://pbs.twimg.com/media/Co242J9WIAAghFZ.jpg', 'url': 'https://t.co/YmiF22vUbQ'}]}, 'entities': {'urls': [{'display_url': 'bbc.in/2aMQgIz', 'indices': [93, 116], 'url': 'https://t.co/XHnRdFGfMc', 'expanded_url': 'http://bbc.in/2aMQgIz'}], 'user_mentions': [], 'symbols': [], 'hashtags': [], 'media': [{'display_url': 'pic.twitter.com/YmiF22vUbQ', 'id_str': '760467152621150208', 'expanded_url': 'http://twitter.com/BBCr4today/status/760467154428977152/photo/1', 'type': 'photo', 'media_url': 'http://pbs.twimg.com/media/Co242J9WIAAghFZ.jpg', 'id': 760467152621150208, 'sizes': {'small': {'w': 680, 'resize': 'fit', 'h': 383}, 'medium': {'w': 1200, 'resize': 'fit', 'h': 675}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}, 'large': {'w': 1920, 'resize': 'fit', 'h': 1080}}, 'indices': [117, 140], 'media_url_https': 'https://pbs.twimg.com/media/Co242J9WIAAghFZ.jpg', 'url': 'https://t.co/YmiF22vUbQ'}]}, 'coordinates': None, 'user': {'lang': 'en', 'id_str': '8170292', 'default_profile': False, 'name': 'BBC Radio 4 Today', 'profile_background_tile': False, 'id': 8170292, 'geo_enabled': False, 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000091666222/0cd53279dee2c0a190b79b7cc5a8ffd1.jpeg', 'friends_count': 13995, 'followers_count': 555513, 'is_translator': False, 'profile_text_color': '000000', 'favourites_count': 1164, 'profile_background_color': 'F5F5F5', 'profile_sidebar_fill_color': 'CCCC99', 'profile_link_color': '222273', 'following': None, 'screen_name': 'BBCr4today', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/458913607133061121/76RyVUuu_normal.jpeg', 'follow_request_sent': None, 'profile_image_url': 'http://pbs.twimg.com/profile_images/458913607133061121/76RyVUuu_normal.jpeg', 'contributors_enabled': False, 'profile_sidebar_border_color': '000000', 'profile_use_background_image': True, 'location': 'Lo ...
# got here
# iterating user mentions
# {'id': 53097744, 'id_str': '53097744', 'screen_name': 'yogital', 'indices': [3, 11], 'name': 'Yogita Limaye'}
# got past loop
# a tweet found
# ...
# got here
# iterating user mentions
# {'id': 3125523251, 'id_str': '3125523251', 'screen_name': 'leithfadel', 'indices': [3, 14], 'name': 'Leith Abou Fadel'}
# got past loop
# a tweet found
# {'lang': 'it', 'id_str': '760598911237038080', 'contributors': None, 'favorited': False, 'source': '<a href="http://publicize.wp.com/" rel="nofollow">WordPress.com</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760598911237038080, 'retweet_count': 0, 'text': 'Non solo Sirte: la rete Isis e il fronte islamista\xa0rivale https://t.co/bq9ULpqwU4', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'entities': {'urls': [{'display_url': 'angolodelgiornalaio.wordpress.com/2016/08/03/non…', 'indices': [58, 81], 'url': 'https://t.co/bq9ULpqwU4', 'expanded_url': 'https://angolodelgiornalaio.wordpress.com/2016/08/03/non-solo-sirte-la-rete-isis-e-il-fronte-islamista-rivale/'}], 'user_mentions': [], 'symbols': [], 'hashtags': []}, 'coordinates': None, 'user': {'lang': 'it', 'id_str': '3431969470', 'default_profile': False, 'name': 'angol del giornalaio', 'profile_background_tile': True, 'id': 3431969470, 'geo_enabled': False, 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/637741320795242496/JYEOSAWG.jpg', 'friends_count': 392, 'followers_count': 376, 'is_translator': False, 'profile_text_color': '000000', 'favourites_count': 186, 'profile_background_color': 'DBE9ED', 'profile_sidebar_fill_color': '000000', 'profile_link_color': 'CC3366', 'following': None, 'screen_name': 'adgiornalaio', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/634086477044023296/Krx9ZjUC_normal.jpg', 'follow_request_sent': None, 'profile_image_url': 'http://pbs.twimg.com/profile_images/634086477044023296/Krx9ZjUC_normal.jpg', 'contributors_enabled': False, 'profile_sidebar_border_color': '000000', 'profile_use_background_image': True, 'location': 'Roma, Lazio', 'url': 'https://angolodelgiornalaio.wordpress.com', 'created_at': 'Wed Aug 19 19:33:24 +0000 2015', 'statuses_count': 172840, 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/637741320795242496/JYEOSAWG.jpg', 'listed_count': 53, 'default_profile_image': False, 'description': 'Informazione, cultura, satira, cattiveria', 'utc_offset': 3600, 'protected': False, 'time_zone': 'London', 'notifications': None, 'verified': False}, 'favorite_count': 0, 'truncated': False, 'in_reply_to_user_id': None, 'created_at': 'Tue Aug 02 22:11:26 +0000 2016', 'in_reply_to_user_id_str': None, 'place': None, 'retweeted': False, 'timestamp_ms': '1470175886340'}
# got here
# got past loop
# a tweet found
# {'lang': 'en', 'id_str': '760598912436699136', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760598912436699136, 'retweet_count': 0, 'text': 'RT @pewresearch: NEW: Number of Refugees to Europe Surges to Record 1.3 Million in 2015 https://t.co/0zuTNN0gMn https://t.co/T1pu2K9zVX', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'extended_entities': {'media': [{'display_url': 'pic.twitter.com/T1pu2K9zVX', 'id_str': '760596498270871552', 'source_user_id_str': '22642788', 'media_url': 'http://pbs.twimg.com/media/Co4ufEDXYAAF6SO.jpg', 'source_status_id_str': '760596506898554881', 'id': 760596498270871552, 'sizes': {'small': {'w': 653, 'resize': 'fit', 'h': 514}, 'medium': {'w': 653, 'resize': 'fit', 'h': 514}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}, 'large': {'w': 653, 'resize': 'fit', 'h': 514}}, 'indices': [112, 135], 'source_status_id': 760596506898554881, 'media_url_https': 'https://pbs.twimg.com/media/Co4ufEDXYAAF6SO.jpg', 'url': 'https://t.co/T1pu2K9zVX', 'expanded_url': 'http://twitter.com/pewresearch/status/760596506898554881/photo/1', 'source_user_id': 22642788, 'type': 'photo'}, {'display_url': 'pic.twitter.com/T1pu2K9zVX', 'id_str': '760596498199506944', 'source_user_id_str': '22642788', 'media_url': 'http://pbs.twimg.com/media/Co4ufDyWcAAhyV2.jpg', 'source_status_id_str': '760596506898554881', 'id': 760596498199506944, 'sizes': {'small': {'w': 338, 'resize': 'fit', 'h': 638}, 'large': {'w': 338, 'resize': 'fit', 'h': 638}, 'medium': {'w': 338, 'resize': 'fit', 'h': 638}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}}, 'indices': [112, 135], 'source_status_id': 760596506898554881, 'media_url_https': 'https://pbs.twimg.com/media/Co4ufDyWcAAhyV2.jpg', 'url': 'https://t.co/T1pu2K9zVX', 'expanded_url': 'http://twitter.com/pewresearch/status/760596506898554881/photo/1', 'source_user_id': 22642788, 'type': 'photo'}, {'display_url': 'pic.twitter.com/T1pu2K9zVX', 'id_str': '760596498216259584', 'source_user_id_str': '22642788', 'media_url': 'http://pbs.twimg.com/media/Co4ufD2WEAAd0se.jpg', 'source_status_id_str': '760596506898554881', 'id': 760596498216259584, 'sizes': {'small': {'w': 304, 'resize': 'fit', 'h': 680}, 'medium': {'w': 326, 'resize': 'fit', 'h': 730}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}, 'large': {'w': 326, 'resize': 'fit', 'h': 730}}, 'indices': [112, 135], 'source_status_id': 760596506898554881, 'media_url_https': 'https://pbs.twimg.com/media/Co4ufD2WEAAd0se.jpg', 'url': 'https://t.co/T1pu2K9zVX', 'expanded_url': 'http://twitter.com/pewresearch/status/760596506898554881/photo/1', 'source_user_id': 22642788, 'type': 'photo'}, {'display_url': 'pic.twitter.com/T1pu2K9zVX', 'id_str': '760596498199502848', 'source_user_id_str': '22642788', 'media_url': 'http://pbs.twimg.com/media/Co4ufDyWYAA_ZP8.jpg', 'source_status_id_str': '760596506898554881', 'id': 760596498199502848, 'sizes': {'small': {'w': 325, 'resize': 'fit', 'h': 450}, 'medium': {'w': 325, 'resize': 'fit', 'h': 450}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}, 'large': {'w': 325, 'resize': 'fit', 'h': 450}}, 'indices': [112, 135], 'source_status_id': 760596506898554881, 'media_url_https': 'https://pbs.twimg.com/media/Co4ufDyWYAA_ZP8.jpg', 'url': 'https://t.co/T1pu2K9zVX', 'expanded_url': 'http://twitter.com/pewresearch/status/760596506898554881/photo/1', 'source_user_id': 22642788, 'type': 'photo'}]}, 'entities': {'urls': [{'display_url': 'pewrsr.ch/2aOGyWa', 'indices': [88, 111], 'url': 'https://t.co/0zuTNN0gMn', 'expanded_url': 'http://pewrsr.ch/2aOGyWa'}], 'user_mentions': [{'id': 22642788, 'id_str': '22642788', 'screen_name': 'pewresearch', 'indices': [3, 15], 'name': 'Pew Research Center'}], 'symbols': [], 'hashtags': [], 'media': [{'display_url': 'pic.twitter.com/T1pu2K9zVX', 'id_str': '7605 ...
# got here
# iterating user mentions
# {'id': 22642788, 'id_str': '22642788', 'screen_name': 'pewresearch', 'indices': [3, 15], 'name': 'Pew Research Center'}
# got past loop
# a tweet found
# {'lang': 'ar', 'id_str': '760598912495386624', 'contributors': None, 'favorited': False, 'source': '<a href="http://zad-muslim.com" rel="nofollow">تطبيق زاد المسلم</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760598912495386624, 'retweet_count': 0, 'text': 'أستغفر الله العظيم وأتوب إليه\n♻️ https://t.co/DHJVQsQZ6S', 'geo': None, 'filter_level': 'low', 'possibly_sensitive': False, 'is_quote_status': False, 'in_reply_to_status_id': None, 'entities': {'urls': [{'display_url': 'zad-muslim.com', 'indices': [33, 56], 'url': 'https://t.co/DHJVQsQZ6S', 'expanded_url': 'http://zad-muslim.com'}], 'user_mentions': [], 'symbols': [], 'hashtags': []}, 'coordinates': None, 'user': {'lang': 'ar', 'id_str': '603892968', 'default_profile': False, 'name': 'Abdulaziz Altamimi', 'profile_background_tile': False, 'id': 603892968, 'geo_enabled': True, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'friends_count': 75, 'followers_count': 80, 'is_translator': False, 'profile_text_color': '666666', 'favourites_count': 293, 'profile_background_color': '1A1B1F', 'profile_sidebar_fill_color': '252429', 'profile_link_color': '2FC2EF', 'following': None, 'screen_name': 'altwiher', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/746704385602895872/nBCHQkuM_normal.jpg', 'follow_request_sent': None, 'profile_image_url': 'http://pbs.twimg.com/profile_images/746704385602895872/nBCHQkuM_normal.jpg', 'contributors_enabled': False, 'profile_sidebar_border_color': '181A1E', 'profile_use_background_image': True, 'location': 'Hail, Kingdom of Saudi Arabia', 'url': None, 'created_at': 'Sat Jun 09 18:21:00 +0000 2012', 'statuses_count': 13459, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'listed_count': 0, 'default_profile_image': False, 'description': 'رحِم الله بوحاً عرف قدر ثقله .. فصمت', 'utc_offset': 10800, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/603892968/1466863425', 'protected': False, 'time_zone': 'Riyadh', 'notifications': None, 'verified': False}, 'favorite_count': 0, 'truncated': False, 'in_reply_to_user_id': None, 'created_at': 'Tue Aug 02 22:11:26 +0000 2016', 'in_reply_to_user_id_str': None, 'place': None, 'retweeted': False, 'timestamp_ms': '1470175886640'}
# got here
# got past loop
# a tweet found
# {'lang': 'en', 'id_str': '760598912843575296', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760598912843575296, 'retweet_count': 0, 'text': "RT @weknowwhatsbest: Obama says Trump is unfit as a leader, but never said that about:\nCastro\nHugo Chavez\nArafat\nIran's Rouhani\nKim Jong-un…", 'geo': None, 'filter_level': 'low', 'is_quote_status': False, 'in_reply_to_status_id': None, 'entities': {'urls': [], 'user_mentions': [{'id': 952112047, 'id_str': '952112047', 'screen_name': 'weknowwhatsbest', 'indices': [3, 19], 'name': 'WH PRESS SECRETARY'}], 'symbols': [], 'hashtags': []}, 'coordinates': None, 'user': {'lang': 'en', 'id_str': '1024656140', 'default_profile': True, 'name': 'Russ Newendyke', 'profile_background_tile': False, 'id': 1024656140, 'geo_enabled': True, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'friends_count': 586, 'followers_count': 281, 'is_translator': False, 'profile_text_color': '333333', 'favourites_count': 702, 'profile_background_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_link_color': '0084B4', 'following': None, 'screen_name': 'RussNewendyke', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2999325014/fb0119ae53dad04ff0d3029fab6f93b2_normal.jpeg', 'follow_request_sent': None, 'profile_image_url': 'http://pbs.twimg.com/profile_images/2999325014/fb0119ae53dad04ff0d3029fab6f93b2_normal.jpeg', 'contributors_enabled': False, 'profile_sidebar_border_color': 'C0DEED', 'profile_use_background_image': True, 'location': None, 'url': None, 'created_at': 'Thu Dec 20 17:19:26 +0000 2012', 'statuses_count': 1465, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'listed_count': 0, 'default_profile_image': False, 'description': None, 'utc_offset': -18000, 'protected': False, 'time_zone': 'Central Time (US & Canada)', 'notifications': None, 'verified': False}, 'favorite_count': 0, 'truncated': False, 'retweeted_status': {'lang': 'en', 'id_str': '760574397585514496', 'contributors': None, 'favorited': False, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id_str': None, 'in_reply_to_screen_name': None, 'id': 760574397585514496, 'retweet_count': 559, 'text': "Obama says Trump is unfit as a leader, but never said that about:\nCastro\nHugo Chavez\nArafat\nIran's Rouhani\nKim Jong-un\nMuslim Brotherhood", 'geo': None, 'filter_level': 'low', 'is_quote_status': False, 'in_reply_to_status_id': None, 'entities': {'urls': [], 'user_mentions': [], 'symbols': [], 'hashtags': []}, 'coordinates': None, 'user': {'lang': 'en', 'id_str': '952112047', 'default_profile': True, 'name': 'WH PRESS SECRETARY', 'profile_background_tile': False, 'id': 952112047, 'geo_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'friends_count': 58548, 'followers_count': 91183, 'is_translator': False, 'profile_text_color': '333333', 'favourites_count': 24172, 'profile_background_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_link_color': '0084B4', 'following': None, 'screen_name': 'weknowwhatsbest', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/760565868279496704/imn_6CAY_normal.jpg', 'follow_request_sent': None, 'profile_image_url': 'http://pbs.twimg.com/profile_images/760565868279496704/imn_6CAY_normal.jpg', 'contributors_enabled': False, 'profile_sidebar_border_color': 'C0DEED', 'profile_use_background_image': True, 'location': 'WH Press Room', 'url': None, 'created_at': 'Fri Nov 16 17:39:25 +0000 2012', 'statuses_count': 4923, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'listed_count': 1205, 'default_profile_image': False, 'description': 'Parody, but mostly the truth & ...
# got here
# iterating user mentions
# {'id': 952112047, 'id_str': '952112047', 'screen_name': 'weknowwhatsbest', 'indices': [3, 19], 'name': 'WH PRESS SECRETARY'}
# got past loop
